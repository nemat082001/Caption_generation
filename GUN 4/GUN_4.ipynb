# %%
N_1 = "Book"
N_2 = "Chocolate"
N_3 = "Organic powder"
N_4 = "a small pack comprising mix plastic components of different items"
N_5 = "An empty rectangle metal box"
N_6 = "An empty round metal box"
N_7 = "Books"
N_8 = "Chocolate"
N_9 = "Book"
N_10 = "cookies box"
N_11 = "cookies box"
N_12 = "Internet Cable"
N_13 = "small plastic items"
N_14 = "Tissue box wrapped in cloth"
N_15 = "Shoes"
N_16 = "Chocolate"
N_17 = "Metal box"
N_18 = "Headphone"
N_19 = "Chocolate"
N_20 = "Chocolate"
N_21 = "Chocolate"
N_22 = "Plastic Bottles overlapped with plastic boxes"
N_23 = "Round metal box"
N_24 = "Wooden piece"
N_25 = "Mix plastic components"
N_26 = "Wooden plate"
N_27 = "Wooden plate"
N_28 = "Round Metal cane"
# N_29 = ""
# N_30 = ""

# %%
M_1 = "Metal mounts"
M_2 = "beater with metallic pans"
M_3 = "a Water bottle having metallic and plastic material"
M_4 = "a Water bottle having metallic and plastic materia"
M_5 = "a Water bottle having metallic and plastic materia"
M_6 = "a Portable hard disk"
M_7 = "a Umbrella"
M_8 = "a Metallic cooking pan"
M_9 = "Nominal cables"
M_10 = "a Portable hard disk"
M_11 = "one Metallic steel spoon"
M_12 = "one Metallic steel spoon"
M_13 = "one steel plate"
M_14 = "Electric socke"
M_15 = "Walky-talky Phone"
M_16 = "Heavy metal"
M_17 = "Heavy metal"
M_18 = "Heavy metal"
M_19 = "Heavy metal"
M_20 = "3 spoons stacked together"
M_21 = "3 spoons stacked together"
# M_22 = ""
# M_23 = ""
# M_24 = ""
# M_25 = ""
# M_26 = ""
# M_27 = ""
# M_28 = ""
# M_29 = ""
# M_30 = ""

# %%
H_1 = "a CD receiver"
H_2 = "a Heavy metal pan (of radius 3 -4 cm)"
H_3 = "Heavy wires"
H_4 = "a Heavy metal pan (small with 3 cm radius)"
H_5 = "Hard disk with wires"
H_6 = "Mantellic TriPort"
H_7 = "a laptop charger"
H_8 = "Heavy wires"
H_9 = "Metallic bolts"
H_10 = "Metal bars"
H_11 = "Heavy metal"
H_12 = "Heavy metal"
H_13 = "Heavy metal"
H_14 = "Heavy metal"
H_15 = "a stack of metallic spoons"
H_16 = "5 to 6 spoons stacked togther for high occlusion"
H_17 = "stack of 5-6 plates for high "
H_18 = "Heavy metal"
H_19 = "Heavy metal"
H_20 = "Heavy metal"
H_21 = "Heavy metal"
H_22 = "Heavy metal"
H_23 = "Heavy metal"
H_24 = "Heavy metal"
H_25 = "Heavy metal"
H_26 = "Heavy metal"
H_27 = "Heavy metal"
H_28 = "Heavy metal"
H_29 = "Heavy metal"
H_30 = "Heavy metal"

# %%
HG_1 = "Sparse metal grid "
HG_2 = "Sparse metal bar"
HG_3 = "Sparse metal bars"
HG_4 = "dense metal grid"
HG_5 = "Sparse metal grid"
HG_6 = "Sparse metal grid"
HG_7 = "Sparse metal bars"
HG_8 = "dense Metal bars"
HG_9 = "dense metal bars"
HG_10 = "sticking pens together"
HG_11 = "Array of dense metal bolts "
HG_12 = "Array of sparse metal bolts"
HG_13 = "Grid of sparse metal bolts"
HG_14 = "Array of sparse metal bolts"
HG_15 = "Grid of dense metal bolts"
HG_16 = "Array of fully dense metal bolt"
HG_17 = "Grid of dense metal bolts"
HG_18 = "Heavy metal"
HG_19 = "Heavy metal"
HG_20 = "Heavy metal"
HG_21 = "Heavy metal"
HG_22 = "Heavy metal"
HG_23 = "Heavy metal"
HG_24 = "Heavy metal"
HG_25 = "Heavy metal"
HG_26 = "Heavy metal"
HG_27 = "Heavy metal"
HG_28 = "Heavy metal"
HG_29 = "Heavy metal"
HG_30 = "Heavy metal"

# %% [markdown]
# Defining variable of Level and conc

# %% [markdown]
# threat=="GUN"

# %%
threat="Rifle"

# %%
    LEVEL_1_conc_1 = f"other normal passenger items"
    LEVEL_1_conc_2 = f"other normal passenger items"
    LEVEL_1_conc_3 = f"other normal passenger items"
    LEVEL_1_conc_4 = f"other normal passenger items"
    
    LEVEL_2_conc_1 = f"{M_1}, {M_2} and other normal passenger items"
    LEVEL_2_conc_2 = f"{M_3}, {M_4} and other normal passenger items"
    LEVEL_2_conc_3 = f"{M_5}, {M_6} and other normal passenger items"
    LEVEL_2_conc_4 = f"{M_7}, {M_8} and other normal passenger items"
    LEVEL_2_conc_5 = f"{M_9}, {M_10} and other normal passenger items"
    LEVEL_2_conc_6 = f"{M_11}, {M_12} and other normal passenger items"
    LEVEL_2_conc_7 = f"{M_11}, {M_13} and other normal passenger items"
    LEVEL_2_conc_8 = f"{M_11}, {M_12}, {M_13} and other normal passenger items"

    # LEVEL_2B_conc_1 = f"{M_1}, {M_2} and other normal passenger items. The {threat} has been disguised in the bag"
    # LEVEL_2B_conc_2 = f"{M_3}, {M_4} and other normal passenger items. The {threat} has been disguised in the bag"
    # LEVEL_2B_conc_3 = f"{M_5}, {M_6} and other normal passenger items. The {threat} has been disguised in the bag"
    # LEVEL_2B_conc_4 = f"{M_7}, {M_8} and other normal passenger items. The {threat} has been disguised in the bag"
    # LEVEL_2B_conc_5 = f"{M_9}, {M_10} and other normal passenger items. The {threat} has been disguised in the bag"
    # LEVEL_2B_conc_6 = f"{M_11}, {M_12} and other normal passenger items. The {threat} has been disguised in the bag"
    # LEVEL_2B_conc_7 = f"{M_11}, {M_13} and other normal passenger items. The {threat} has been disguised in the bag"
    # LEVEL_2B_conc_8 = f"{M_11}, {M_12}, {M_13} and other normal passenger items. The {threat} has been disguised in the bag"
    
    LEVEL_3_conc_1 = f"{M_1}, {M_2}, {H_1}, and {H_2} and other normal passenger items"
    LEVEL_3_conc_2 = f"{M_3} ,{M_4}, {H_3}, and {H_4} and other normal passenger items"
    LEVEL_3_conc_3 = f"{M_5} ,{M_6}, {H_5}, and {H_6} and other normal passenger items"
    LEVEL_3_conc_4 = f"{M_7} ,{M_8}, {H_7}, and {H_8} and other normal passenger items"
    LEVEL_3_conc_5 = f"{M_9}, {M_10}, {H_15}, and {H_10} and other normal passenger items"
    LEVEL_3_conc_6 = f"{M_11}, {M_12}, {H_2}, and {H_3} and other normal passenger items"
    LEVEL_3_conc_7 = f"{M_11}, {M_13}, {H_7}, and {H_16} and other normal passenger items"
    LEVEL_3_conc_8 = f"{M_11}, {M_12}, {M_13}, {H_3}, and {H_7} and other normal passenger items"
    LEVEL_3_conc_9 = f"{M_11}, {M_12}, {M_17}, and {H_3} and other normal passenger items"
    
    LEVEL_4A_conc_1 = f"{M_1}, {M_12}, and other normal passenger items. The {threat} are half covered by {H_16}"
    LEVEL_4A_conc_2 = f"{M_11}, {M_4}, and other normal passenger items. The {threat} are half covered by {H_17}"
    LEVEL_4A_conc_3 = f"{M_3}, {M_12}, and other normal passenger items. The {threat} are half covered by {H_17}"
    LEVEL_4A_conc_4 = f"{M_13}, {M_12}, and other normal passenger items. The {threat} are half covered by {H_17}"
    LEVEL_4A_conc_5 = f"{M_9}, {M_10}, and other normal passenger items. The {threat} are half covered by {H_15} and {H_10}"
    LEVEL_4A_conc_6 = f"{M_11}, {M_12}, and other normal passenger items. The {threat} are half covered by {H_2} and {H_3}"
    LEVEL_4A_conc_7 = f"{M_11}, {M_13}, and other normal passenger items. The {threat} are half covered by {H_2} and {H_3}"
    LEVEL_4A_conc_8 = f"{M_11}, {M_12}, and {M_13}, and other normal passenger items. The {threat} are half covered by {H_3} and {H_7}"
    LEVEL_4A_conc_9 = f"{M_11}, {M_12}, and {M_17}, and other normal passenger items. The {threat} are half covered by {H_3}"
    
    LEVEL_4B_conc_1 = f"{M_1}, {M_12}, and other normal passenger items. The {threat} are half covered by {H_16} with cables spread below it"
    LEVEL_4B_conc_2 = f"{M_11}, {M_4}, and other normal passenger items. The {threat} are half covered by {H_17} with cables spread below it"
    LEVEL_4B_conc_3 = f"{M_3}, {M_12}, and other normal passenger items. The {threat} are half covered by {H_17} with cables spread below it"
    LEVEL_4B_conc_4 = f"{M_13}, {M_12}, and other normal passenger items. The {threat} are half covered by {H_17} with cables spread below it"
    LEVEL_4B_conc_5 = f"{M_9}, {M_10}, and other normal passenger items. The {threat} are half covered by {H_15} and {H_10} with cables spread below it"
    LEVEL_4B_conc_6 = f"{M_11}, {M_12}, and other normal passenger items. The {threat} are half covered by {H_2} and {H_3} with cables spread below it"
    LEVEL_4B_conc_7 = f"{M_11}, {M_13}, and other normal passenger items. The {threat} are half covered by {H_2} and {H_3} with cables spread below it"
    LEVEL_4B_conc_8 = f"{M_11}, {M_12}, and {M_13}, and other normal passenger items. The {threat} are half covered by {H_3} and {H_7} with cables spread below it"
    LEVEL_4B_conc_9 = f"{M_11}, {M_12}, and {M_17}, and other normal passenger items. The {threat} are half covered by {H_3} with cables spread below it"
    
    LEVEL_4C_conc_1 = f"{M_1}, {M_2}, and other normal passenger items. The {threat} are half covered by {HG_1}"
    LEVEL_4C_conc_2 = f"{M_3}, {M_4}, and other normal passenger items. The {threat} are half covered by {HG_2}"
    LEVEL_4C_conc_3 = f"{M_5}, {M_6}, and other normal passenger items. The {threat} are half covered by {HG_3}"
    LEVEL_4C_conc_4 = f"{M_7}, {M_8}, and other normal passenger items. The {threat} are half covered by {HG_4}"
    LEVEL_4C_conc_5 = f"{M_9}, {M_10}, and other normal passenger items. The {threat} are half covered by {HG_5}"
    LEVEL_4C_conc_6 = f"{M_11}, {M_12}, and other normal passenger items. The {threat} are half covered by {HG_1}"
    LEVEL_4C_conc_7 = f"{M_11}, {M_13}, and other normal passenger items. The {threat} are half covered by {HG_1}"
    LEVEL_4C_conc_8 = f"{M_11}, {M_12}, and {M_13} and other normal passenger items. The {threat} are half covered by {HG_1}"
    LEVEL_4C_conc_9 = f"{M_11}, {M_12}, and {M_13} and other normal passenger items. The {threat} are half covered by {HG_1}"
    
    LEVEL_4D_conc_1 = f"{M_1}, {M_2}, and other normal passenger items. The {threat} are half covered by Hangers"
    LEVEL_4D_conc_2 = f"{M_3}, {M_15}, and other normal passenger items. The {threat} are half covered by Hangers"
    LEVEL_4D_conc_3 = f"{M_7}, {M_6}, and other normal passenger items. The {threat} are half covered by Hangers"
    LEVEL_4D_conc_4 = f"{M_8}, {M_14}, and other normal passenger items. The {threat} are half covered by Hangers"
    LEVEL_4D_conc_5 = f"{M_9}, {M_10}, and other normal passenger items. The {threat} are half covered by Hangers"
    LEVEL_4D_conc_6 = f"{M_11}, {M_12}, and other normal passenger items. The {threat} are half covered by Hangers"
    LEVEL_4D_conc_7 = f"{M_11}, {M_13}, and other normal passenger items. The {threat} are half covered by Hangers"
    LEVEL_4D_conc_8 = f"{M_11}, {M_12}, {M_13} and other normal passenger items. The {threat} are half covered by Hangers"
    LEVEL_4D_conc_9 = f"{M_11}, {M_12}, {M_13} and other normal passenger items. The {threat} are half covered by Hangers"
    
    LEVEL_5_conc_1 = f"{M_1} and {M_2} and other normal passenger items. The {threat} are fully covered by {HG_1} along with {HG_2} and it is on the top"
    LEVEL_5_conc_2 = f"{M_3}, {M_4} and other normal passenger items. The {threat} are fully covered by {HG_1} along with {HG_2} and it on the top"
    LEVEL_5_conc_3 = f"{M_5}, {M_6} and other normal passenger items. The {threat} are fully covered by {HG_3} and it is on the top"
    LEVEL_5_conc_4 = f"{M_7}, {M_8} and other normal passenger items. The{threat} are fully covered by {HG_4} and it is on the top"
    LEVEL_5_conc_5 = f"{M_9},{M_10} and other normal passenger items. The {threat} are fully covered by {HG_5} and it is on the top"
    LEVEL_5_conc_6 = f"{M_11}, {M_12} and random grid of {HG_13},{HG_15} and {HG_17} partially overlapped over {M_1} and other normal passenger items. The {threat} is on the top"
    LEVEL_5_conc_7 = f"{M_13}, {M_14},{HG_11} kept over {HG_12} and {HG_14} kept over {M_1} and other normal passenger items. The {threat} is on the top"
    LEVEL_5_conc_8 = f"{M_13}, {M_14}, {HG_11} kept over {HG_12} and {HG_14} along with {HG_17} kept over {M_1} and other normal passenger items. The {threat} is on the top"
    LEVEL_5_conc_9 = f"{H_13}, {H_14}, {HG_11} kept over {HG_12} and {HG_14} kept over {M_1} and other normal passenger items. The {threat} is on the top "
    
    LEVEL_6_conc_1 = f"{M_1}, {M_2}  and other normal passenger items. The {threat} are fully covered covered by {H_2} and {H_7}"
    LEVEL_6_conc_2 = f"{M_5}, {M_6}  and other normal passenger items. The {threat} are fully covered covered by {H_7} and {H_2}"
    LEVEL_6_conc_3 = f"{M_9}, {M_10} and other normal passenger items. The {threat} are fully covered by {H_1} and are parallel with the cabels"
    LEVEL_6_conc_4 = f"{M_9}, {M_10} and other normal passenger items. The {threat} are along with {M_7} and fully inside {H_7}"
    LEVEL_6_conc_5 = f"{M_11}, {M_13} and other normal passenger items. The {threat} are fully covered by {H_17} and {H_2}"
    LEVEL_6_conc_6 = f"{M_11}, {M_13} and other normal passenger items. The {threat} are fully covered by {H_17} and {H_16} "
    LEVEL_6_conc_7 = f"{M_11}, {M_13} and other normal passenger items. The {threat} are fully covered by {H_15} and {H_16} "
    LEVEL_6_conc_8 = f"{M_11}, {M_12}, {M_13} and other normal passenger items. The {threat} are fully covered by {H_3} and {H_7}"
    LEVEL_6_conc_9 = f"{M_11}, {M_12}, {M_17} and other normal passenger items. The {threat} are fully covered by {H_3}"
    
    LEVEL_7A_conc_1 = f"{M_1}, {M_2}, and other normal passenger items. The {threat} are fully covered covered by {H_2},{M_7} and Cables"
    LEVEL_7A_conc_2 = f"{M_5}, {M_6}, and other normal passenger items. The {threat} are fully covered covered by {H_7} and Cables"
    LEVEL_7A_conc_3 = f"{M_9}, {M_10}, and other normal passenger items. The {threat} are fully covered by {H_1} parallel with {H_2} and Cables"
    LEVEL_7A_conc_4 = f"{M_9}, {M_10}, and other normal passenger items. The {threat} are fully covered covered by {H_2} and Cables"
    LEVEL_7A_conc_5 = f"{M_11}, {M_13}, and other normal passenger items. The {threat} are fully covered by {H_17} and {H_1} and Cables"
    LEVEL_7A_conc_6 = f"{M_11}, {M_13}, and other normal passenger items. The {threat} are fully covered by {H_16}, {H_17} and Cables"
    LEVEL_7A_conc_7 = f"{M_11}, {M_13}, and other normal passenger items. The {threat} are fully covered by {H_15}, {H_16} and Cables"
    LEVEL_7A_conc_8 = f"{M_11}, {M_12}, {M_13}, and other normal passenger items. The {threat} are fully covered by {H_3}, {H_7} and Cables"
    LEVEL_7A_conc_9 = f"{M_11}, {M_12}, {M_17}, and other normal passenger items. The {threat} are fully covered by {H_3} and Cables"
    
    LEVEL_7B_conc_1 = f"{M_1}, {M_14}, and other normal passenger items. The {threat} are fully covered covered by {H_2} along with umbrella {M_7},and hangers are kept over it"
    LEVEL_7B_conc_2 = f"{M_5}, {M_6}, and other normal passenger items. The {threat} are fully covered covered by {H_2} parallel with {H_7}, and hangers are kept over it"
    LEVEL_7B_conc_3 = f"{M_9}, {M_10}, and other normal passenger items. The {threat} are fully covered by {H_1} parallel with cabels, and hangers are kept over it"
    LEVEL_7B_conc_4 = f"{M_11}, {M_13}, and other normal passenger items. The {threat} are fully covered covered by {H_1} parallel with {H_17}, and hangers are kept over it"
    LEVEL_7B_conc_5 = f"{M_11}, {M_13}, and other normal passenger items. The {threat} are fully covered by {H_15}, {H_16} and {H_17}, and hangers are kept over it"
    LEVEL_7B_conc_6 = f"{M_11}, {M_13}, and other normal passenger items. The {threat} are fully covered by {H_1} parallel with {H_16},and {H_15}, and hangers are kept over it"
    LEVEL_7B_conc_7 = f"{M_11}, {M_13}, and other normal passenger items. The {threat} are fully covered by {H_1} and {H_16}, and hangers are kept over it"
    LEVEL_7B_conc_8 = f"{M_11}, {M_12}, {M_13}, and other normal passenger items. The {threat} are fully covered by {H_3} and {H_7}, and hangers are kept over it"
    LEVEL_7B_conc_9 = f"{M_11}, {M_12}, {M_17}, and other normal passenger items. The {threat} are fully covered by {H_3}, and hangers are kept over it"
    
    LEVEL_8_conc_1 = f"{M_1}, {M_2}, and other normal passenger items. The {threat} are superimposed covered by {H_2} over {H_1} along with {H_8}"
    LEVEL_8_conc_2 = f"{M_3}, {M_4}, and other normal passenger items. The {threat} are superimposed covered by {H_2} over {H_1} along with {M_7}"
    LEVEL_8_conc_3 = f"{M_5}, {M_6}, and other normal passenger items. The {threat} are superimposed covered by {H_2} over {M_7}"
    LEVEL_8_conc_4 = f"{M_7}, {M_8}, and other normal passenger items. The {threat} are superimposed covered by {H_2} over {H_13}"
    LEVEL_8_conc_5 = f"{M_9}, {M_10}, and other normal passenger items. The {threat} are superimposed covered by {H_13} over {H_1}"
    LEVEL_8_conc_6 = f"{M_11}, {M_13}, and other normal passenger items. The {threat} are superimposed {H_16},and {M_17} over {H_1}"
    LEVEL_8_conc_7 = f"{M_11}, {M_13}, and other normal passenger items. The {threat} are superimposed by {H_1} and {H_16} over {H_1}"
    LEVEL_8_conc_8 = f"{M_11}, {M_12}, {M_13}, and other normal passenger items. The {threat} are superimposed by {H_3} and {H_7} over {H_1}"
    LEVEL_8_conc_9 = f"{M_11}, {M_12}, {M_17}, and other normal passenger items. The {threat} are superimposed by {H_3} over {H_1}"
    
    LEVEL_9_conc_1 = f"{M_1}, {M_2}, and other normal passenger items. The {threat} are superimposed by Heavy metals with fully covering {HG_1} parallel with {HG_2}"
    LEVEL_9_conc_2 = f"{M_5}, {M_6}, and other normal passenger items. The {threat} are superimposed by Heavy metals with fully covering {HG_6},{H_3} and cables"
    LEVEL_9_conc_3 = f"{M_7}, {M_8}, and other normal passenger items. The {threat} are superimposed by Heavy metals  with fully covering {HG_4}, {H_3} and cables"
    LEVEL_9_conc_4 = f"{M_11}, {M_13}, and other normal passenger items. The {threat} are superimposed by {HG_14} and {HG_15} kept aside with fully covering {HG_17} and {HG_9}"
    LEVEL_9_conc_5 = f"{M_11}, {M_13}, and other normal passenger items. The {threat} are superimposed by {H_14} and {H_15} kept only aside with fully covering {HG_13} along with {HG_9},{H_15} and {H_16}"
    LEVEL_9_conc_6 = f"{M_11}, {M_13}, and other normal passenger items. The {threat} are superimposed by {HG_16} and {HG_11} kept aside only over {HG_17},{H_15}, and {H_16}"
    LEVEL_9_conc_7 = f"{M_11}, {M_13}, and other normal passenger items. The {threat} are superimposed by {H_8} and {H_2} and it is kept over the {HG_13} and {H_8}"
    LEVEL_9_conc_8 = f"{M_11}, {M_13}, and other normal passenger items. The {threat} are placed over {H_15} and {H_16} and the head of the it is covered by one stack of spoons"
    LEVEL_9_conc_9 = f"{M_11}, {M_13}, and other normal passenger items. The {threat} are placed perpendicular to the {H_15} and {H_16}"
    LEVEL_9_conc_10 = f"{M_11}, {M_13}, and other normal passenger items. The {threat} is placed over {H_15} and {H_16} and the head and the hand of the {threat} are aligned with {H_15} and {H_16}"
    
    LEVEL_10_conc_1 = f"{M_1}, {M_2}, {H_7}, and other normal passenger items. The {threat} is over with fully covering {HG_1} and {HG_2} with some random cables and random screws and {HG_16} is kept in the bag for distraction"
    LEVEL_10_conc_2 = f"{M_1}, {M_2}, {H_7}, and other normal passenger items {threat} are over the cable and some random cables kept in the bag for distraction"
    LEVEL_10_conc_3 = f"{M_1}, {M_2}, {H_7}, and other normal passenger items {threat} are over the hanger along with {HG_16} and {H_17} and some random hanger kept in the bag for distraction"
    LEVEL_10_conc_4 = f"{M_1}, {M_2}, {H_7}, and other normal passenger items {threat} are over the hanger and the cables and random hanger and cable kept in the bag for distraction"
    LEVEL_10_conc_5 = f"{M_1}, {M_2}, {H_7}, and other normal passenger items. The {threat} are over the hanger and cables along with {M_7} and random cables and screws kept for distraction"
    LEVEL_10_conc_6 = f"{M_1}, {M_2}, {H_7}, and other normal passenger items {threat} are over the cables along with {M_7} and random screws and cable kept for distraction"
    LEVEL_10_conc_7 = f"{M_5}, {M_6}, and other normal passenger items {threat} are over the {HG_6}, {H_2}, {H_16} and cables and random cables kept in bag for distraction"
    LEVEL_10_conc_8 = f"{M_5}, {M_6}, and other normal passenger items {threat} are kept over {HG_6}, {H_2} and cables and some random cables kept in the bag for distraction"
    LEVEL_10_conc_9 = f"{M_7}, {M_8}, and other normal passenger items. The {threat} are kept over the {H_17} and {HG_4} and cables and some random cables for distrcation"
    LEVEL_10_conc_10 = f"{M_11}, {M_13}, and other normal passenger items, {HG_14} and {HG_15} kept aside of {threat}, and {threat} are kept over the {HG_17} with some random screws along with {H_15} and {H_16}"
    LEVEL_10_conc_11 = f"{M_11}, {M_13}, and other normal passenger items, {H_8} and {H_2} kept aside of {threat}, and {threat} are over the {HG_13} with some random screws along with {H_15} and {H_16}"
    LEVEL_10_conc_12 = f"{M_9}, {M_10}, and other normal passenger items and {H_1} and {H_17} partially covering the {threat} and some random cables kept beside it"
    LEVEL_10_conc_13 = f"{M_14}, {M_15}, {M_7}  and other normal passenger items. The {threat} are inside the {M_7} and some random cables kept in the bag"
    LEVEL_10_conc_14 = f"{M_11}, {M_13}, {H_17} and other normal passenger items are half covering the {threat}along with {H_7} and aome random cables kept in the bag"
    LEVEL_10_conc_15 = f"{M_11}, {M_13}, {H_15} and other normal passenger items and {H_16} item are half covering the {threat} along with {H_7} and random cables kept in the bag"

# %%
Location_1="Centre"
Location_2="Corner"

# %%
Phi_1="horizontally"
Phi_2="tilted upward at an inclined angle"
# Phi_3="180 Degree"

# %%
Theta_1="0 Degree"
Theta_2="180 Degree"

# %%
bag_1="suitcase"
bag_2="valise"
bag_3="valise"
bag_4="valise"
bag_5="valise"
bag_6="valise"

# %%
threat_4 =["Long-range rifle","Scoped rifle"]

# threat_2 =["Automatic Pistol","Full-Size Pistol"]

# %%
import pandas as pd
import re
# Read the Excel file
input_file = 'Gun4.xlsx'  
df = pd.read_excel(input_file)
df.shape
# Out:
# (1126, 1)

# %%
filenames = df['Xray image']
def extract_numbers(part):
    match = re.search(r'\d+[a-zA-Z]*', part)
    return match.group() if match else ''
processed_data = []
for filename in filenames:
    words_list = filename.split('_')
    words_list[-1] = words_list[-1].split('.')[0]  
    numbers_list = [extract_numbers(part) for part in words_list]
    processed_data.append(numbers_list)

for words in processed_data:
    print(words)
# Out:
# ['', '4', '1', '1', '1', '1', '1', '1', '1']
# ['', '4', '1', '1', '1', '1', '1', '1', '2']
# ['', '4', '1', '1', '1', '1', '1', '1', '3']
# ['', '4', '1', '1', '1', '1', '1', '1', '4']
# ['', '4', '1', '1', '1', '1', '2', '1', '1']
# ['', '4', '1', '1', '1', '1', '2', '1', '2']
# ['', '4', '1', '1', '1', '1', '2', '1', '3']
# ['', '4', '1', '1', '1', '1', '2', '1', '4']
# ['', '4', '1', '1', '1', '2', '2', '1', '1']
# ['', '4', '1', '1', '1', '2', '2', '1', '2']
# ['', '4', '1', '1', '1', '2', '2', '1', '3']
# ['', '4', '1', '1', '1', '2', '2', '1', '4']
# ['', '4', '1', '1', '2', '1', '1', '1', '1']
# ['', '4', '1', '1', '2', '1', '1', '1', '2']
# ['', '4', '1', '1', '2', '1', '1', '1', '3']
# ['', '4', '1', '1', '2', '1', '1', '1', '4']
# ['', '4', '1', '1', '2', '1', '2', '1', '1']
# ['', '4', '1', '1', '2', '1', '2', '1', '2']
# ['', '4', '1', '1', '2', '1', '2', '1', '3']
# ['', '4', '1', '1', '2', '1', '2', '1', '4']
# ['', '4', '1', '1', '2', '2', '2', '1', '1']
# ...

# %%
processed_data=[x[1:] for x in processed_data]

# %%
import random
picture_to_caption=[]
list_of_verbs=["showing","displaying","illustrating","showcasing"]
list_of_location=["placed", "positioned"]
for items in processed_data:
    
        var_name="threat_"+str(items[0])
        threat_lst=globals()[var_name]
        
        th=random.choice(threat_lst)
        threat =th
        
        var_name0="bag_"+str(items[1])
        var_name1= "LEVEL_" + str(items[2]) + "_conc_" + str(items[3])
        var_name2 = "Location_" + str(items[4])
        var_name3 = "Phi_" + str(items[5])
        var_name4 = "Theta_" + str(items[6])
        var_name5= "Picture_"+str(items[7])
        caption = f"An X-ray image of a " +globals()[var_name0] 
        caption += f" {random.choice(list_of_verbs)} threat items, specifically  "

        caption+=th
        
        caption += f' {random.choice(list_of_location)} '+ globals()[var_name3]   
            # caption +=' and phi '+ globals()[var_name4]
        caption +=', at the ' + globals()[var_name2] +' of the bag along with ' 
        var_name11=globals()[var_name1]
        caption +=var_name11
        caption+='.'
        print(caption)
        picture_to_caption.append(caption)
# Out:
# An X-ray image of a suitcase displaying threat items, specifically  Scoped rifle placed horizontally, at the Centre of the bag along with other normal passenger items.
# An X-ray image of a suitcase illustrating threat items, specifically  Scoped rifle positioned horizontally, at the Centre of the bag along with other normal passenger items.
# An X-ray image of a suitcase showing threat items, specifically  Long-range rifle placed horizontally, at the Centre of the bag along with other normal passenger items.
# An X-ray image of a suitcase showcasing threat items, specifically  Long-range rifle placed horizontally, at the Centre of the bag along with other normal passenger items.
# An X-ray image of a suitcase showing threat items, specifically  Long-range rifle positioned tilted upward at an inclined angle, at the Centre of the bag along with other normal passenger items.
# ...

# %%
len(picture_to_caption)
# Out:
# 1996

# %%
import pandas as pd
df1=pd.DataFrame(picture_to_caption)
df2=pd.DataFrame(filenames)

# %%
df2
# Out:
#                              Xray image
# 0     gun1_B1_L1_C1_Loc1_phi1_th1_1.png
# 1     gun1_B1_L1_C1_Loc1_phi1_th1_2.png
# 2     gun1_B1_L1_C1_Loc1_phi1_th1_3.png
# 3     gun1_B1_L1_C1_Loc1_phi1_th1_4.png
# 4     gun1_B1_L1_C1_Loc1_phi2_th1_1.png
# ...                                 ...
# 1991  gun2_B1_L9_C7_Loc1_phi1_th1_3.png
# 1992  gun2_B1_L9_C7_Loc1_phi1_th1_4.png
# 1993  gun2_B1_L9_C7_Loc1_phi2_th1_1.png
# 1994  gun2_B1_L9_C7_Loc1_phi2_th1_2.png
# 1995  gun2_B1_L9_C7_Loc2_phi2_th1_1.png
#
# [1996 rows x 1 columns]

# %%
merged_df = pd.merge(df2, df1, left_index=True, right_index=True, how='inner')

# %%
merged_df['Caption']=merged_df[0]

# %%
merged_df=merged_df.drop(0,axis=1)

# %%
merged_df.shape
# Out:
# (1996, 2)

# %%
import csv
merged_df.to_csv('GUN_1_3_Caption3.csv', index=False, quoting=csv.QUOTE_NONE, sep='\t')
