# %%
import os

def explore_directory(directory_path, leaf_directories):
    for root, dirs, files in os.walk(directory_path):
        if not dirs:
            picture_count = sum(1 for file in files if file.lower().endswith(('.png', '.jpg', '.jpeg', '.gif')))
            if picture_count > 0:
             
                picture_names = [file for file in files if file.lower().endswith(('.png', '.jpg', '.jpeg', '.gif'))]
                leaf_directories.append((root, picture_names))

# Put the file path here
directory_path = r'C:\Users\munna\OneDrive\Desktop\khalifa_project\\'
leaf_directories = []
explore_directory(directory_path, leaf_directories)

for leaf_dir, picture_names in leaf_directories:
    print("Leaf directory:", leaf_dir)
    print("Pictures:", picture_names)

# %% [markdown]
# Define threat

# %%
threat='Pliers'

# %% [markdown]
# Defining variable of Level and conc

# %%
LEVEL_1_conc_1 = "Normal density items"
LEVEL_1_conc_2 = "Normal density items"
LEVEL_1_conc_3 = "Normal density items"
LEVEL_1_conc_4 = "Normal density items"

LEVEL_2_conc_1 = "Normal, Medium level 1 and Medium level 2 density items"
LEVEL_2_conc_2 = "Normal, Medium level 3 and Medium level 4 density items"
LEVEL_2_conc_3 = "Normal, Medium level 5 and Medium level 6 density items"
LEVEL_2_conc_4 = "Normal, Medium level 7 and Medium level 8 density items"
LEVEL_2_conc_5 = "Normal, Medium level 9 and Medium level 10 density items"
LEVEL_2_conc_6 = "Normal, Medium level 11 and Medium level 12 density items"
LEVEL_2_conc_7 = "Normal, Medium level 11 and Medium level 13 density items"
LEVEL_2_conc_8 = "Normal, Medium level 11, Medium level 12 and Medium level 13 density items"

LEVEL_3_conc_1 = "Normal, Medium level (1,2),and Heavy level (1,2) dense items"
LEVEL_3_conc_2 = "Normal, Medium level (3,4),and Heavy level (3,4) dense items"
LEVEL_3_conc_3 = "Normal, Medium level (5,6),and Heavy level (5,6) dense items"
LEVEL_3_conc_4 = "Normal, Medium level (7,8),and Heavy level (7,8) dense items"
LEVEL_3_conc_5 = "Normal, Medium level (9,10),and Heavy level (15,10) dense items"
LEVEL_3_conc_6 = "Normal, Medium level (11,12),and Heavy level (2,3) dense items"
LEVEL_3_conc_7 = "Normal, Medium level (11,13),and Heavy level (7,16) dense items"
LEVEL_3_conc_8 = "Normal, Medium level (11,12,13),and Heavy level (3,7) dense items"
LEVEL_3_conc_9 = "Normal, Medium level (11,12,17),and Heavy level (3) dense items"

LEVEL_4_A_conc_1 = "Normal, Medium level (1,12),and with Half covering Heavy level (16) dense items"
LEVEL_4_A_conc_2 = "Normal, Medium level (11,4),and with Half covering Heavy level (17) dense items"
LEVEL_4_A_conc_3 = "Normal, Medium level (3,12),and with Half covering Heavy level (17) dense items"
LEVEL_4_A_conc_4 = "Normal, Medium level (13,12),and with Half covering Heavy level (17) dense items"
LEVEL_4_A_conc_5 = "Normal, Medium level (9,10),and with Half covering Heavy level (15,10) dense items"
LEVEL_4_A_conc_6 = "Normal, Medium level (11,12),and with Half covering Heavy level (2,3) dense items"
LEVEL_4_A_conc_7 = "Normal, Medium level (11,13),and with Half covering Heavy level (7,16) dense items"
LEVEL_4_A_conc_8 = "Normal, Medium level (11,12,13),and with Half covering Heavy level (3,7) dense items"
LEVEL_4_A_conc_9 = "Normal, Medium level (11,12,17),and with Half covering Heavy level (3) dense items"

LEVEL_4_B_conc_1 = "Normal, Medium level (1,12), with Half covering Heavy level (16) dense items and Cables spread below it"
LEVEL_4_B_conc_2 = "Normal, Medium level (11,4), with Half covering Heavy level (17) dense items and Cables spread below it"
LEVEL_4_B_conc_3 = "Normal, Medium level (3,12), with Half covering Heavy level (17) dense items and Cables spread below it"
LEVEL_4_B_conc_4 = "Normal, Medium level (13,12), with Half covering Heavy level (17) dense items and Cables spread below it"
LEVEL_4_B_conc_5 = "Normal, Medium level (9,10), with Half covering Heavy level (15,10) dense items and Cables spread below it"
LEVEL_4_B_conc_6 = "Normal, Medium level (11,12), with Half covering Heavy level (2,3) dense items and Cables spread below it"
LEVEL_4_B_conc_7 = "Normal, Medium level (11,13), with Half covering Heavy level (7,16) dense items and Cables spread below it"
LEVEL_4_B_conc_8 = "Normal, Medium level (11,12,13), with Half covering Heavy level (3,7) dense items and Cables spread below it"
LEVEL_4_B_conc_9 = "Normal, Medium level (11,12,17), with Half covering Heavy level (3) dense items and Cables spread below it"

LEVEL_4_C_conc_1 = "Normal, Medium level (1,2) dense items and Half covering Array Sticks Level (1) "
LEVEL_4_C_conc_2 = "Normal, Medium level (3,4) dense items and Half covering Array Sticks Level (2) "
LEVEL_4_C_conc_3 = "Normal, Medium level (5,6) dense items and Half covering Array Sticks Level (3) "
LEVEL_4_C_conc_4 = "Normal, Medium level (7,8) dense items and Half covering Array Sticks Level (4) "
LEVEL_4_C_conc_5 = "Normal, Medium level (9,10) dense items and Half covering Array Sticks Level (5) "
LEVEL_4_C_conc_6 = "Normal, Medium level (11,12) dense items and Half covering Array Sticks Level (1) "
LEVEL_4_C_conc_7 = "Normal, Medium level (11,13) dense items and Half covering Array Sticks Level (1) "
LEVEL_4_C_conc_8 = "Normal, Medium level (11,12,13) dense items and Half covering Array Sticks Level (1) "
LEVEL_4_C_conc_9 = "Normal, Medium level (11,12,1) dense items and Half covering Array Sticks Level (1) "

LEVEL_4_D_conc_1 = "Normal, Medium level (1,2) dense items and Half covering Hanger Level (1) "
LEVEL_4_D_conc_2 = "Normal, Medium level (3,4) dense items and Half covering Hanger Level (1) "
LEVEL_4_D_conc_3 = "Normal, Medium level (5,6) dense items and Half covering Hanger Level (1) "
LEVEL_4_D_conc_4 = "Normal, Medium level (7,8) dense items and Half covering Hanger Level (1) "
LEVEL_4_D_conc_5 = "Normal, Medium level (9,10) dense items and Half covering Hanger Level (1) "
LEVEL_4_D_conc_6 = "Normal, Medium level (11,12) dense items and Half covering Hanger Level (1) "
LEVEL_4_D_conc_7 = "Normal, Medium level (11,13) dense items and Half covering Hanger Level (1) "
LEVEL_4_D_conc_8 = "Normal, Medium level (11,12,13) dense items and Half covering Hanger Level (1) "
LEVEL_4_D_conc_9 = "Normal, Medium level (11,12,1) dense items and Half covering Hanger Level (1)"

LEVEL_5_conc_1 = "Normal, Medium level (1,2) dense items and full covering Array Sticks Level (1) "
LEVEL_5_conc_2 = "Normal, Medium level (3,4) dense items and full covering Array Sticks Level (2) "
LEVEL_5_conc_3 = "Normal, Medium level (5,6) dense items and full covering Array Sticks Level (3) "
LEVEL_5_conc_4 = "Normal, Medium level (7,8) dense items and full covering Array Sticks Level (4) "
LEVEL_5_conc_5 = "Normal, Medium level (9,10) dense items and full covering Array Sticks Level (5) "
LEVEL_5_conc_6 = "Normal, Medium level (11,12) dense items and full covering Array Sticks Level (1) "
LEVEL_5_conc_7 = "Normal, Medium level (11,13) dense items and full covering Array Sticks Level (1) "
LEVEL_5_conc_8 = "Normal, Medium level (11,12,13) dense items and full covering Array Sticks Level (1) "
LEVEL_5_conc_9 = "Normal, Medium level (11,12,1) dense items and full covering Array Sticks Level (1) "

LEVEL_6_conc_1 = "Normal, Medium level (1,2),and full covering Heavy level (2) dense items"
LEVEL_6_conc_2 = "Normal, Medium level (5,6),and full covering Heavy level (7) dense items"
LEVEL_6_conc_3 = "Normal, Medium level (9.10),and full covering Heavy level (1) dense items"
LEVEL_6_conc_4 = "Normal, Medium level (9,10),and full covering Heavy level (7) dense items"
LEVEL_6_conc_5 = "Normal, Medium level (11,13),and full covering Heavy level (17) dense items"
LEVEL_6_conc_6 = "Normal, Medium level (11,13),and full covering Heavy level (16,17) dense items"
LEVEL_6_conc_7 = "Normal, Medium level (11,13),and full covering Heavy level (15,16) dense items"
LEVEL_6_conc_8 = "Normal, Medium level (11,12,13),and full covering Heavy level (3,7) dense items"
LEVEL_6_conc_9 = "Normal, Medium level (11,12,17),and full covering Heavy level (3) dense items"

LEVEL_7_A_conc_1 = "Normal, Medium level (1,2), full covering Heavy level (2) dense items, and with full covering Cables"
LEVEL_7_A_conc_2 = "Normal, Medium level (5,6), full covering Heavy level (7) dense items, and with full covering Cables"
LEVEL_7_A_conc_3 = "Normal, Medium level (9.10), full covering Heavy level (1) dense items, and with full covering Cables"
LEVEL_7_A_conc_4 = "Normal, Medium level (9,10), full covering Heavy level (7) dense items, and with full covering Cables"
LEVEL_7_A_conc_5 = "Normal, Medium level (11,13), full covering Heavy level (17) dense items, and with full covering Cables"
LEVEL_7_A_conc_6 = "Normal, Medium level (11,13), full covering Heavy level (16,17) dense items, and with full covering Cables"
LEVEL_7_A_conc_7 = "Normal, Medium level (11,13), full covering Heavy level (15,16) dense items, and with full covering Cables"
LEVEL_7_A_conc_8 = "Normal, Medium level (11,12,13), full covering Heavy level (3,7) dense items, and with full covering Cables"
LEVEL_7_A_conc_9 = "Normal, Medium level (11,12,17), full covering Heavy level (3) dense items, and with full covering Cables"

LEVEL_7_B_conc_1 = "Normal, Medium level (1,14), full covering Heavy level (2) dense items, and over Hangers"
LEVEL_7_B_conc_2 = "Normal, Medium level (5,6), full covering Heavy level (7) dense  items, and over Hangers"
LEVEL_7_B_conc_3 = "Normal, Medium level (9.10), full covering Heavy level (1) dense  items, and over Hangers"
LEVEL_7_B_conc_4 = "Normal, Medium level (9,10), full covering Heavy level (7) dense  items, and over Hangers"
LEVEL_7_B_conc_5 = "Normal, Medium level (11,13), full covering Heavy level (17) dense  items, and over Hangers"
LEVEL_7_B_conc_6 = "Normal, Medium level (11,13), full covering Heavy level (16,17) dense  items, and over Hangers"
LEVEL_7_B_conc_7 = "Normal, Medium level (11,13), full covering Heavy level (15,16) dense  items, and over Hangers"
LEVEL_7_B_conc_8 = "Normal, Medium level (11,12,13), full covering Heavy level (3,7) dense  items, and over Hangers"
LEVEL_7_B_conc_9 = "Normal, Medium level (11,12,17), full covering Heavy level (3) dense  items, and over Hangers"

LEVEL_8_conc_1 = "Normal, Medium level (1,2),and superimposed Heavy level (2) over (1) densely items"
LEVEL_8_conc_2 = "Normal, Medium level (3,4),and superimposed Heavy level (2) over (1) densely items"
LEVEL_8_conc_3 = "Normal, Medium level (5.6),and superimposed Heavy level (2) over (1) densely items"
LEVEL_8_conc_4 = "Normal, Medium level (7,8),and superimposed Heavy level (2) over (1) densely items"
LEVEL_8_conc_5 = "Normal, Medium level (9,10),and superimposed Heavy level (2) over (1) density items"
LEVEL_8_conc_6 = "Normal, Medium level (11,13),and superimposed Heavy level (16,17) over (1) density items"
LEVEL_8_conc_7 = "Normal, Medium level (11,13),and superimposed Heavy level (15,16) over (1) density items"
LEVEL_8_conc_8 = "Normal, Medium level (11,12,13),and superimposed Heavy level (3,7) over (1) density items"
LEVEL_8_conc_9 = "Normal, Medium level (11,12,17),and superimposed Heavy level (3) over (1) density items"


LEVEL_9_conc_1 = "Normal, Medium level (1,2),and superimposed Heavy items in terms of density with fully covering grid of level (1)"
LEVEL_9_conc_2 = "Normal, Medium level (5,6),and superimposed Heavy items in terms of density with fully covering grid of level (6)"
LEVEL_9_conc_3 = "Normal, Medium level (7.8),and superimposed Heavy items in terms of density with fully covering grid of level (4)"
LEVEL_9_conc_4 = "Normal, Medium level (7,8),and superimposed Heavy level (14,15) items in terms of density aside with fully covering grid of level (17)"
LEVEL_9_conc_5 = "Normal, Medium level (9,10),and superimposed Heavy level (14,15) items in terms of density aside with fully covering grid of level (13)"
LEVEL_9_conc_6 = "Normal, Medium level (11,13),and superimposed Heavy  level (16,11) items in terms of density aside with fully covering grid of level (17)"
LEVEL_9_conc_7 = "Normal, Medium level (11,13),and superimposed Heavys level (8,2) items in terms of density with fully covering grid of level (13)"
LEVEL_9_conc_8 = "Normal, Medium level (11,12,13),and superimposed Heavy items in terms of density with fully covering grid of level (1)"
LEVEL_9_conc_9 = "Normal, Medium level (11,12,17),and superimposed Heavy items in terms of density with fully covering grid of level (1)"
LEVEL_9_conc_10 = "Normal, Medium level (11,12,17),and superimposed Heavy items in terms of density with fully covering grid of level (1)"

LEVEL_10_conc_1 = f"Normal, Medium level (1,2),and Heavy level (7) densely items with fully covering grid of level (1) over {threat} and some random cables and random screws for distraction"
LEVEL_10_conc_2 = f"Normal, Medium level (1,2),and Heavy level (7) densely items, {threat} is over cable and some random cables for distraction"
LEVEL_10_conc_3 = f"Normal, Medium level (1,2),and Heavy level (7) densely items, {threat} is over hanger and some random hanger"
LEVEL_10_conc_4 = f"Normal, Medium level (1,2),and Heavy level (7) densely items, {threat} is over hanger and cable and random hanger and cable"
LEVEL_10_conc_5 = f"Normal, Medium level (1,2),and Heavy level (7) densely items, {threat} is over cables and random cables and screws for distraction"
LEVEL_10_conc_6 = f"Normal, Medium level (1,2),and Heavy level (7) densely items, {threat} is over cables and random screws and cable for distraction"
LEVEL_10_conc_7 = f"Normal, Medium level (5,6) densely items, {threat} over array stick level (6) and cables and random cables"
LEVEL_10_conc_8 = f"Normal, Medium level (5,6) densely items, {threat} over array stick level (6) and over heavy items level (2) and cables and random cables"
LEVEL_10_conc_9 = f"Normal, Medium level (7,8) densely items, {threat} over array stick level (4) and cables and random cables"
LEVEL_10_conc_10 = f"Normal, Medium level (11,13) denselyitems, array stick level (14,15) aside of {threat}, and it is over the array stick level (17) with random screws"
LEVEL_10_conc_11 = f"Normal, Medium level (11,13) densely items, Heavy items level (8,2) aside of {threat}, and it is over array stick level (13) with random screws"
LEVEL_10_conc_12 = f"Normal, Medium level (9,10) densely items and Heavy level (1) densely items is partially covering the {threat} and random cables beside"
LEVEL_10_conc_13 = f"Normal, Medium level (14,15,7) densely items and {threat} is inside the Medium level (7) dense item and random cables kept in the bag"
LEVEL_10_conc_14 = f"Normal, Medium level (11,13) densely items and Heavy level (14) dense items half covering the {threat}, and random cables kept in the bag"
LEVEL_10_conc_15 = f"Normal, Medium level (11,13) densely items and Heavy level (15,16) dense items half covering the {threat} and random cables kept in the bag"

# %% [markdown]
# Location

# %%
Location_1="Centre"
Location_2="Corner"

# %% [markdown]
# PHI

# %%
Phi_1="0 Degree"
Phi_2="90 Degree"
Phi_3="180 Degree"

# %% [markdown]
# Theta

# %%
Theta_1="0 Degree"
Theta_2="180 Degree"

# %%
for leaf_dir in leaf_directories:
    print(leaf_dir)
print(len(leaf_directories))

# %%
import os

number = []
picture names


for leaf_dir, _ in leaf_directories:
    directories = leaf_dir.split(os.path.sep)
    cap = []

    for directory in directories:
        if directory.startswith("LEVEL-"):
            level_number = directory.split("-")[1]
            if ' ' in level_number:
                level_number = level_number.replace(' ', '_')
                level_number = level_number.replace('(', '').replace(')', '')
            cap.append(level_number)
        if directory.startswith("conc-"):
            level_number = directory.split("-")[1]
            cap.append(level_number)
        if directory.startswith("location-"):
            level_number = directory.split("-")[1]
            cap.append(level_number)
        if directory.startswith("phi-"):
            level_number = directory.split("-")[1]
            cap.append(level_number)
        if directory.startswith("theata-"):
            level_number = directory.split("-")[1]
            cap.append(level_number)
    number.append(cap)

for items in number:
    print(items)

print(len(number))

# %%
import os

cap_picture_dict = {}

for leaf_dir, picture_names in leaf_directories:
    directories = leaf_dir.split(os.path.sep)
    cap = []

    for directory in directories:
        if directory.startswith("LEVEL-"):
            level_number = directory.split("-")[1]
            if ' ' in level_number:
                level_number = level_number.replace(' ', '_')
                level_number = level_number.replace('(', '').replace(')', '')
            cap.append(level_number)
        if directory.startswith("conc-"):
            level_number = directory.split("-")[1]
            cap.append(level_number)
        if directory.startswith("location-"):
            level_number = directory.split("-")[1]
            cap.append(level_number)
        if directory.startswith("phi-"):
            level_number = directory.split("-")[1]
            cap.append(level_number)
        if directory.startswith("theata-"):
            level_number = directory.split("-")[1]
            cap.append(level_number)
    
  
    if tuple(cap) not in cap_picture_dict:
        cap_picture_dict[tuple(cap)] = picture_names
    else:
        cap_picture_dict[tuple(cap)].extend(picture_names)


for cap, picture_names in cap_picture_dict.items():
    print("Cap:", cap)
    print("Pictures:", picture_names)

# %%
import random
picture_to_caption={}
list_of_verbs=["shows", "presents", "exhibits","displays","illustrate","showcase"]

for items in cap_picture_dict:
    names_of_picture=cap_picture_dict[items]
    for picture in names_of_picture:
        
        caption = f"This X-ray image {random.choice(list_of_verbs)} "
        caption+= threat+ ' along with '
        if len(items)!=0:
       
            var_name = "LEVEL_" + str(items[0]) + "_conc_" + str(items[1])
            var_name2 = "Location_" + str(items[2])
            var_name3 = "Phi_" + str(items[3])
            var_name4 = "Theta_" + str(items[4])
            list_of_location=["located", "positioned"]
        
            caption += globals()[var_name]+ f' {random.choice(list_of_location)} at the'  
            caption +=' ' + globals()[var_name2]  
            caption += ' with theta '+ globals()[var_name3] 
            caption +=' and phi '+ globals()[var_name4]
            caption+='.'
            
            print(caption)
            picture_to_caption[picture]=caption

# %%
print(picture_to_caption)

# %%
import pandas as pd
df = pd.DataFrame(list(picture_to_caption.items()), columns=['Image', 'Caption'])
df.to_csv('raw_data3.csv',index=False)

# %%
print(df.head())
